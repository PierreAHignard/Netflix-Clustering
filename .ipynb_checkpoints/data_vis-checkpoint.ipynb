# %% [markdown]
# # Challenge 1: Netflix Data Analysis

# %% [markdown]
# ##### Team: Clément FORNAGE - Clément EDOUARD - Quentin DENIS - Pierre-Antoine HIGNARD NAUDEAU - Marin HEROGUER - Romain ACHARD

# %% [markdown]
# ### 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ### 2. Import Data

# %%
path = "../data/"
movies = pd.read_csv(path + "netflix_titles.csv")

# %% [markdown]
# ### 3. First Data Exploration

# %% [markdown]
# We display the first few rows to understand the data structure

# %%
movies.head(50)
# Out:
#    show_id     type                                              title
# 0       s1    Movie                               Dick Johnson Is Dead  \
# 1       s2  TV Show                                      Blood & Water
# 2       s3  TV Show                                          Ganglands
# 3       s4  TV Show                              Jailbirds New Orleans
# 4       s5  TV Show                                       Kota Factory
# 5       s6  TV Show                                      Midnight Mass
# 6       s7    Movie                   My Little Pony: A New Generation
# 7       s8    Movie                                            Sankofa
# 8       s9  TV Show                      The Great British Baking Show
# 9      s10    Movie                                       The Starling
# 10     s11  TV Show                Vendetta: Truth, Lies and The Mafia
# 11     s12  TV Show                                   Bangkok Breaking
# ...

# %% [markdown]
# We print the shape of the dataset

# %%
movies.shape
# Out:
# (8807, 12)

# %% [markdown]
# We display basic information about the dataset

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ### 4. Features Selection

# %% [markdown]
# We first delete the variables that seem to be irrelevant for our analysis.
#
# Variable "show_id" is irrelevant because we already have an id for each row and variable "date_added" is not interesting in our study of the dataset.

# %%
movies_cleaned = movies.drop(["show_id", "date_added"], axis = 1)
movies_cleaned
# Out:
#          type                  title         director
# 0       Movie   Dick Johnson Is Dead  Kirsten Johnson  \
# 1     TV Show          Blood & Water              NaN
# 2     TV Show              Ganglands  Julien Leclercq
# 3     TV Show  Jailbirds New Orleans              NaN
# 4     TV Show           Kota Factory              NaN
# ...       ...                    ...              ...
# 8802    Movie                 Zodiac    David Fincher
# 8803  TV Show            Zombie Dumb              NaN
# 8804    Movie             Zombieland  Ruben Fleischer
# 8805    Movie                   Zoom     Peter Hewitt
# 8806    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country
# 0                                                   NaN  United States  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# ...

# %% [markdown]
# ### 5. Missing Data Analysis

# %% [markdown]
# We print the missing values per column to see how many we miss

# %%
movies_cleaned.isnull().sum()
# Out:
# type               0
# title              0
# director        2634
# cast             825
# country          831
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
#With percentages
movies_cleaned.isnull().mean() * 100
# Out:
# type             0.000000
# title            0.000000
# director        29.908028
# cast             9.367549
# country          9.435676
# release_year     0.000000
# rating           0.045418
# duration         0.034064
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %%
msno.matrix(movies_cleaned, color = (0.16, 0.50, 0.73))
plt.title("Netflix Dataset Missing Values Matrix per Variable", fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Netflix Dataset Missing Values Matrix per Variable')

# %% [markdown]
# We now treat the missing values with different methods depending on the variable:

# %% [markdown]
# For "rating" and "duration" variables, we just delete the few rows with missing values as we just have few NA values in each of these variables

# %%
movies_cleaned = movies_cleaned.dropna(subset = ["rating", "duration"])

# %% [markdown]
# For "director", "cast" and "country" variables, we can replace NA values by "No director", "No cast" and "No country" values

# %%
movies_cleaned.loc[:, "director"] = movies_cleaned["director"].fillna("No_director")
movies_cleaned.loc[:, "cast"] = movies_cleaned["cast"].fillna("No_cast")
movies_cleaned.loc[:, "country"] = movies_cleaned["country"].fillna("No_country")

# %% [markdown]
# We now check we don't have any missing values anymore

# %%
movies_cleaned.isnull().sum()
# Out:
# type            0
# title           0
# director        0
# cast            0
# country         0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# We can also check the new shape of the dataset

# %%
movies_cleaned.shape
# Out:
# (8800, 10)

# %% [markdown]
# ### 6. Look to remove duplicates

# %% [markdown]
# We check our dataset to identify possible duplicates

# %%
movies_cleaned.duplicated().sum()
# Out:
# 0

# %% [markdown]
# We got 0 duplicates in our dataset

# %% [markdown]
# ### 7. Dataset Transformation

# %% [markdown]
# We first look at the "duration" variable to see its format and its different values

# %%
print(movies_cleaned['duration'].unique())
# Out:
# ['90 min' '2 Seasons' '1 Season' '91 min' '125 min' '9 Seasons' '104 min'
#  '127 min' '4 Seasons' '67 min' '94 min' '5 Seasons' '161 min' '61 min'
#  '166 min' '147 min' '103 min' '97 min' '106 min' '111 min' '3 Seasons'
#  '110 min' '105 min' '96 min' '124 min' '116 min' '98 min' '23 min'
#  '115 min' '122 min' '99 min' '88 min' '100 min' '6 Seasons' '102 min'
#  '93 min' '95 min' '85 min' '83 min' '113 min' '13 min' '182 min' '48 min'
#  '145 min' '87 min' '92 min' '80 min' '117 min' '128 min' '119 min'
#  '143 min' '114 min' '118 min' '108 min' '63 min' '121 min' '142 min'
#  '154 min' '120 min' '82 min' '109 min' '101 min' '86 min' '229 min'
#  '76 min' '89 min' '156 min' '112 min' '107 min' '129 min' '135 min'
#  '136 min' '165 min' '150 min' '133 min' '70 min' '84 min' '140 min'
#  '78 min' '7 Seasons' '64 min' '59 min' '139 min' '69 min' '148 min'
#  '189 min' '141 min' '130 min' '138 min' '81 min' '132 min' '10 Seasons'
# ...

# %% [markdown]
# We can then split the variable in 2 variables: "duration_value" and "duration_unit"

# %%
movies_cleaned[["duration_value", "duration_unit"]] = movies_cleaned["duration"].str.split(" ", expand = True)
movies_cleaned.loc[movies_cleaned["duration_unit"] == "Season", "duration_unit"] = "Seasons"
movies_cleaned
# Out:
# /var/folders/mq/9w31n29d4kq7p98h20gsn8h00000gn/T/ipykernel_69444/844823077.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_cleaned[["duration_value", "duration_unit"]] = movies_cleaned["duration"].str.split(" ", expand = True)
#          type                  title         director
# 0       Movie   Dick Johnson Is Dead  Kirsten Johnson  \
# 1     TV Show          Blood & Water      No_director
# 2     TV Show              Ganglands  Julien Leclercq
# 3     TV Show  Jailbirds New Orleans      No_director
# 4     TV Show           Kota Factory      No_director
# ...       ...                    ...              ...
# 8802    Movie                 Zodiac    David Fincher
# 8803  TV Show            Zombie Dumb      No_director
# ...

# %% [markdown]
# We check we have the right number of values in each new variable created

# %%
movies_cleaned[["duration_value", "duration_unit"]].count()
# Out:
# duration_value    8800
# duration_unit     8800
# dtype: int64

# %% [markdown]
# We now want to simplify the "rating" variable in order to create clearer categories and facilitate the next steps of the analysis

# %% [markdown]
# First, we examine the "rating" variable to understand its format and the different values it contains

# %%
print(movies_cleaned['rating'].unique())
# Out:
# ['PG-13' 'TV-MA' 'PG' 'TV-14' 'TV-PG' 'TV-Y' 'TV-Y7' 'R' 'TV-G' 'G'
#  'NC-17' 'NR' 'TV-Y7-FV' 'UR']

# %% [markdown]
# We can now create the clearer categories: "Kids", "Teens" and "Adults" and simplify the "rating" variable

# %%
rating_categories = {'TV-Y': 'Kids', 'TV-G': 'Kids', 'TV-Y7': 'Kids', 'TV-Y7-FV': 'Kids', 'G': 'Kids',
                    'PG': 'Teens', 'TV-PG': 'Teens', 'PG-13': 'Teens', 'TV-14': 'Teens',
                    'R': 'Adults', 'TV-MA': 'Adults', 'NC-17': 'Adults', 'NR': 'Adults', 'UR': 'Adults'
                    }

movies_cleaned['rating_category'] = movies['rating'].map(rating_categories)
movies_cleaned
# Out:
# /var/folders/mq/9w31n29d4kq7p98h20gsn8h00000gn/T/ipykernel_69444/2403207580.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_cleaned['rating_category'] = movies['rating'].map(rating_categories)
#          type                  title         director
# 0       Movie   Dick Johnson Is Dead  Kirsten Johnson  \
# 1     TV Show          Blood & Water      No_director
# 2     TV Show              Ganglands  Julien Leclercq
# 3     TV Show  Jailbirds New Orleans      No_director
# 4     TV Show           Kota Factory      No_director
# ...       ...                    ...              ...
# 8802    Movie                 Zodiac    David Fincher
# 8803  TV Show            Zombie Dumb      No_director
# ...

# %% [markdown]
# We check we have the right number of values in the new variable "rating_category" created

# %%
movies_cleaned[["rating_category"]].count()
# Out:
# rating_category    8800
# dtype: int64

# %% [markdown]
# ### 8. Some Data Visualizations

# %% [markdown]
# ### 9. Movie Recommendation System

# %% [markdown]
# Nous avons fait le choix d'opter pour un modèle de recommandations de films permettant à partir d'un titre de film (ou de série) de pouvoir recommander à un utilisateur un certain nombres de films similaires selon des critères précisément choisis par nos soins.

# %%
#Nombre d'échantillons par catégorie : ici 50-50, donc min(nombre de Movies, nombre de TV Shows)
n = min(movies_cleaned["type"].value_counts())

# Échantillonnage stratifié
random_sample = movies_cleaned.groupby("type", group_keys = False).apply(lambda x: x.sample(n=n, random_state=42))

# %% [markdown]
# Ainsi, nous commençons tout d'abord par mettre toutes les variables que l'on souhaite utiliser dans une seule et unique variable (sous la forme d'une chaîne de caractères) qui nous servira plus tard lors de l'implémentation du modèle avec la technique TF-IDF.
#
# Le choix a été fait ici de ne pas conserver la variable "type" car trop déséquilibrée entre ses valeurs "TV Show" et "Movie" dans le dataset ce qui pourrait déséquilibrer les scores trop fortement en faveur de la valeur la plus rare (ici, "TV Show"). L'idée d'effectuer un échantillon aléatoire afin d'obtenir 50% pour chaque valeur a été évoquée mais nous nous sommes rendu compte que trop de films/séries pourraient alors ne pas être recommandés par la suite car supprimés.
#
# Pour les variables "director" et "cast", leur retrait est plutôt lié au fait que beaucoup de leurs valeurs ne sont présentes qu'une seule fois dans le dataset, ce qui pourrait engendre des biais dans notre modèle.

# %%
movies_cleaned["all_combined_variables"] = (
    #movies_cleaned["type"].astype(str) + " " +
    #movies_cleaned["director"].astype(str) + " " +
    #movies_cleaned["cast"].astype(str) + " " +
    movies_cleaned["country"].astype(str) + " " +
    movies_cleaned["release_year"].astype(str) + " " +
    movies_cleaned["listed_in"].astype(str) + " " +
    movies_cleaned["description"].astype(str) + " " +
    movies_cleaned["duration_value"].astype(str) + " " +
    movies_cleaned["duration_unit"].astype(str) + " " +
    movies_cleaned["rating_category"].astype(str)
)

#We put all values in "lower" format in order to avoid problems of case
movies_cleaned["all_combined_variables"] = movies_cleaned["all_combined_variables"].str.lower()
# Out:
# /var/folders/mq/9w31n29d4kq7p98h20gsn8h00000gn/T/ipykernel_69444/2270203600.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_cleaned["all_combined_variables"] = (
# /var/folders/mq/9w31n29d4kq7p98h20gsn8h00000gn/T/ipykernel_69444/2270203600.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_cleaned["all_combined_variables"] = movies_cleaned["all_combined_variables"].str.lower()

# %% [markdown]
# On applique par la suite la fonction de notre modèle permettant de créer une matrice avec:
#
# - pour les noms de colonnes, les mots principaux trouvés au sein de la variable regroupante créée et décrivant chaque film avec toutes les variables
#
# - pour les noms des lignes, c'est tout simplement les indices des films dans l'ordre du dataset initial
#
# - pour les valeurs, c'est le poids que chaque mot possède dans l'"identité" d'un film (plus le mot apparaît souvent, plus le score est bas car le mot a moins d'impact dans l'identité du film et vice versa)

# %%
tfidf = TfidfVectorizer(stop_words = ["english", "no_director", "no_cast", "no_country"], max_features = 5000)
#stop_words: permet de ne pas prendre en compte les petits mots inutiles en anglais avec "english" ainsi que les autres mots dans la liste
#max_features: décrit le nombre maximal de mots (donc de colonnes) autorisé à être lu au total via le modèle

tfidf_matrix = tfidf.fit_transform(movies_cleaned["all_combined_variables"])

# %% [markdown]
# On crée la matrice des similarités qui donne un score plus ou moins élevé en fonction de la similarité entre 2 films/séries. Ces scores se basent sur les vecteurs de poids de mots créés juste ci-dessus et sur leur similarité cosinus.

# %%
similarity_matrix = cosine_similarity(tfidf_matrix, tfidf_matrix)
print("Exemple de matrice de similarité: \n\n", similarity_matrix[:5, :5])
# Out:
# Exemple de matrice de similarité:
#
#  [[1.         0.02241419 0.03863453 0.01360636 0.0443279 ]
#  [0.02241419 1.         0.1079347  0.06214359 0.1177995 ]
#  [0.03863453 0.1079347  1.         0.04724284 0.17912227]
#  [0.01360636 0.06214359 0.04724284 1.         0.05272038]
#  [0.0443279  0.1177995  0.17912227 0.05272038 1.        ]]

# %% [markdown]
# On définit maintenant la fonction qui va nous permettre de créer une liste contenant un nombre choisi de films à recommander à partir d'un titre de film choisi également.
#
# La fonction va se baser sur la matrice de similarité pour trouver les n films avec le score de similarité cosinus le plus élevé par rapport au film donné en argument.

# %%
def get_recommendations_from_movie_title(title, recommendations_number = 10):
    #print(movies_cleaned[movies_cleaned["title"] == title])
    recommendations = []
    
    index_movie = movies_cleaned[movies_cleaned["title"] ==  title].index[0] #movie index in the dataset and so, in the matrix
    sorted_indices = np.argsort(similarity_matrix[index_movie])[::-1] #tri décroissant des scores à l'index du film cible et renvoi des indices des colonnes triées
    sorted_scores = similarity_matrix[index_movie][sorted_indices][1:recommendations_number + 1] #renvoi des scores triés dans l'ordre décroissant pour le film cible
    
    #sorted_scores = sorted(similarity_matrix[index_movie], reverse = True)[1:recommendations_number + 1]
    #print(sorted_indices[1:recommendations_number + 1])
    #print(sorted_scores)

    #création du data frame des films à recommander pour le film cible
    recommendations = movies_cleaned.iloc[sorted_indices[1:recommendations_number + 1]][["title", "country", "type", "listed_in", "rating_category"]]

    #ajout de la variable "score" au data frame représentant les scores de chaque film recommandé
    recommendations["score"] = sorted_scores
    #for m in sorted_scores:
    #recommendations.append(movies_cleaned.iloc[similarity_matrix.columns.get_loc(m)][["title", "type", "listed_in", "rating"]])

    return recommendations

# %% [markdown]
# On test notre système de recommandations en affichant des recommandations pour 3 films/séries choisis par nos soins afin de visualiser la cohérence des résultats obtenus

# %%
# Test the recommendation system

print("\n🎬 Testing Recommendation System\n\n")

test_titles = ['Jaws', 'Arrow', 'Angry Birds']

for test_title in test_titles:
    if test_title in movies_cleaned['title'].values:
        print(f"\n\n📺 Recommendations for '{test_title}':\n\n")
        recommendations = get_recommendations_from_movie_title(test_title, 5)
        for idx, row in recommendations.iterrows():
            #print(f"  {row['title'][:40]:40s} | Score: {row['score']:.3f} | Type: {row['type']:40s} | Country: {row['country']:40s} | Genre: {row['listed_in']:40s}")
            print(f"{row['title'][:40]:40} | " f"Score: {row['score']:<6.3f} | " f"Type: {row['type'][:15]:1} | " f"Country: {row['country'][:20]:20} | " f"Genre: {row['listed_in'][:25]:30}")
# Out:
# 🎬 Testing Recommendation System
#
#
#
#
# 📺 Recommendations for 'Jaws':
#
#
# Jaws 2                                   | Score: 0.408  | Type: Movie | Country: United States        | Genre: Dramas, Horror Movies, Th
# Jaws: The Revenge                        | Score: 0.401  | Type: Movie | Country: United States        | Genre: Action & Adventure, Horro
# Jaws 3                                   | Score: 0.278  | Type: Movie | Country: United States        | Genre: Action & Adventure, Horro
# Pinkfong & Baby Shark's Space Adventure  | Score: 0.251  | Type: Movie | Country: United States, South | Genre: Children & Family Movies
# Tremors: Shrieker Island                 | Score: 0.210  | Type: Movie | Country: United States        | Genre: Action & Adventure, Horro
#
#
# 📺 Recommendations for 'Arrow':
#
#
# The Flash                                | Score: 0.257  | Type: TV Show | Country: United States        | Genre: Crime TV Shows, TV Action
# ...
